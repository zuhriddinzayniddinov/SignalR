# %% [markdown]
# <a href="https://colab.research.google.com/github/zuhriddinzayniddinov/SignalR/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("salom")
# Out:
# salom

# %% [markdown]
# # Hello world
# - salom
# - [sd]("https://colab.research.google.com/?utm_source=scs-index#")

# %%
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import tensorflow as tf
import keras

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import pandas as pd

files = pd.read_excel('./One/tblData1.xlsx')

files.head()
# Out:
#    Shartnoma № Shartnoma sanasi           Xarid holati  \
# 0          912       14.09.2023      Созданная покупка
# 1          911       14.09.2023      Созданная покупка
# 2          910       05.09.2023      Созданная покупка
# 3          909       24.08.2023  Реализованная покупка
# 4          908       24.08.2023  Холдированная покупка
#
#          Yetkazib beruvchi                                     Qiymat  \
# 0            ООО PETROCHEM   40 800\n                            so'm
# 1                Модератор       12\n                            so'm
# 2                Модератор       12\n                            so'm
# 3       СП SANGIO INDUSTRY  128 064\n                            so'm
# 4  ООО NURAFSHON AVTOCENTR   30 000\n                            so'm
#
#   To'lov holati Shartnoma Hisob faktura Elektron chek
# 0    Не оплачен   To'lash      signedBy       Saqlash
# 1    Не оплачен   To'lash      signedBy       Saqlash
# ...
